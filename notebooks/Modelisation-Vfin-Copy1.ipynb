# %%
# !pip install imblearn
# !pip install xgboost
# !pip install --user numba shap
# Out:
# Requirement already satisfied: imblearn in c:\users\farid\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\farid\anaconda3\lib\site-packages (from imblearn) (0.12.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\farid\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (3.5.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\farid\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.9.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\farid\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.24.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\farid\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\farid\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.5.0)
# Requirement already satisfied: xgboost in c:\users\farid\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: scipy in c:\users\farid\anaconda3\lib\site-packages (from xgboost) (1.9.1)
# Requirement already satisfied: numpy in c:\users\farid\anaconda3\lib\site-packages (from xgboost) (1.24.4)
# Requirement already satisfied: numba in c:\users\farid\appdata\roaming\python\python39\site-packages (0.59.1)
# Requirement already satisfied: shap in c:\users\farid\appdata\roaming\python\python39\site-packages (0.45.1)
# Requirement already satisfied: numpy<1.27,>=1.22 in c:\users\farid\anaconda3\lib\site-packages (from numba) (1.24.4)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\farid\appdata\roaming\python\python39\site-packages (from numba) (0.42.0)
# Requirement already satisfied: scikit-learn in c:\users\farid\anaconda3\lib\site-packages (from shap) (1.5.0)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\farid\anaconda3\lib\site-packages (from shap) (4.64.1)
# Requirement already satisfied: slicer==0.0.8 in c:\users\farid\anaconda3\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: cloudpickle in c:\users\farid\anaconda3\lib\site-packages (from shap) (2.0.0)
# Requirement already satisfied: pandas in c:\users\farid\anaconda3\lib\site-packages (from shap) (1.4.4)
# Requirement already satisfied: scipy in c:\users\farid\anaconda3\lib\site-packages (from shap) (1.9.1)
# Requirement already satisfied: packaging>20.9 in c:\users\farid\anaconda3\lib\site-packages (from shap) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\farid\anaconda3\lib\site-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: colorama in c:\users\farid\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\farid\anaconda3\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\farid\anaconda3\lib\site-packages (from pandas->shap) (2022.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\farid\anaconda3\lib\site-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\farid\anaconda3\lib\site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\farid\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)

# %%
# !pip install --upgrade scikit-learn --user
# Out:
# Requirement already satisfied: scikit-learn in c:\users\farid\anaconda3\lib\site-packages (1.5.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\farid\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\farid\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\farid\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\farid\anaconda3\lib\site-packages (from scikit-learn) (1.24.4)

# %% [markdown]
# # Projet de Modèle de Scoring
#
# ## Introduction
# Ce projet vise à développer un modèle de scoring de crédit qui prédit la probabilité qu'un client rembourse son crédit. Ce modèle aidera la société financière à prendre des décisions éclairées sur l'octroi de prêts.
#
#
# ## Importation des Libraries

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.5.0

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, FixedThresholdClassifier
from sklearn.metrics import roc_auc_score, roc_curve, classification_report, confusion_matrix, make_scorer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline as make_pipeline_imblearn
from imblearn.under_sampling import RandomUnderSampler
import mlflow
import mlflow.sklearn
from collections import Counter
from xgboost import XGBClassifier

# %% [markdown]
# # Configuration de MLFlow

# %%
import mlflow
from mlflow import log_metric, log_param, log_artifacts

# Définir l'URI de suivi de MLFlow
path_mlruns = '../mlruns/'
mlflow.set_tracking_uri(path_mlruns)

# Affiche le URI de tracking actuel
print(mlflow.get_tracking_uri())
# Out:
# ../mlruns/

# %%
'''
# Créer une nouvelle expérience et obtenir son ID
experiment_id = mlflow.create_experiment("model_scoring")
print(f"ID de la nouvelle expérience : {experiment_id}")
'''
# Out:
# '\n# Créer une nouvelle expérience et obtenir son ID\nexperiment_id = mlflow.create_experiment("model_scoring")\nprint(f"ID de la nouvelle expérience : {experiment_id}")\n'

# %% [markdown]
# ## Chargement des Données

# %%
path_data_processed = "../data/processed/"
data = pd.read_csv(path_data_processed + 'processed_data_train.csv', index_col=[0])
data_test = pd.read_csv(path_data_processed + 'processed_data_test.csv', index_col=[0])

# %% [markdown]
# ## Séparation des données en ensembles d'entraînement et de test

# %%
X = data.drop('TARGET', axis=1)
y = data['TARGET']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %% [markdown]
# ## Définition des Fonctions Utiles

# %%
def plot_roc_curve(y_test, y_scores, title="ROC Curve"):
    fpr, tpr, _ = roc_curve(y_test, y_scores)
    auc = roc_auc_score(y_test, y_scores)
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'AUC = {auc:.2f}')
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(title)
    plt.legend()
    plt.show()
    return auc

# %%
def business_cost(y_true, y_pred, cost_fn=10, cost_fp=1):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    return -(cost_fn * fn + cost_fp * fp)  # Minimize business cost

# %%
def business_score(y_true, y_pred, cost_fn=cost_fn, cost_fp=cost_fp):
    """
    Calculate the business score for predictions.

    Parameters:
    - y_true: array, true labels.
    - y_pred: array, predicted labels.
    - cost_fn: int, cost associated with a false negative.
    - cost_fp: int, cost associated with a false, positive.

    Returns:
    - float, normalized business score between 0 and 1.
    """
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    total_cost = cost_fn * fn + cost_fp * fp
    max_cost = cost_fn * (fn + tp) + cost_fp * (fp + tn)  # worst case scenario: all predictions are wrong
    
    # Normalize and subtract from 1 to flip the scale: higher is better
    return 1 - (total_cost / max_cost)

# %% [markdown]
# ## Prétraitement des Données
# ### Vérification des Valeurs Manquantes

# %%
print(f"Missing values: {data.isna().sum().sum()} ({data.isna().sum().sum()/data.size:.2%})")
# Out:
# Missing values: 36088183 (19.62%)

# %%
# Affichage des colonnes pour vérification
print(data.columns)

# Définition des features numériques et catégorielles
numeric_features = [col for col in X.columns if X[col].dtype in ['int64', 'float64']]
categorical_features = [col for col in X.columns if X[col].dtype == 'object']

# Affichage des types de features
print("Numeric Features:", numeric_features)
print("Categorical Features:", categorical_features)
# Out:
# Index(['TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY', 'REGION_POPULATION_RELATIVE',
#        ...
#        'PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN',
#        'PREV_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN',
#        'PREV_PRODUCT_COMBINATION_POS household with interest_MEAN',
#        'PREV_PRODUCT_COMBINATION_POS household without interest_MEAN',
#        'PREV_PRODUCT_COMBINATION_POS industry with interest_MEAN',
#        'PREV_PRODUCT_COMBINATION_POS industry without interest_MEAN',
#        'PREV_PRODUCT_COMBINATION_POS mobile with interest_MEAN',
#        'PREV_PRODUCT_COMBINATION_POS mobile without interest_MEAN',
#        'PREV_PRODUCT_COMBINATION_POS other with interest_MEAN',
#        'PREV_PRODUCT_COMBINATION_POS others without interest_MEAN'],
#       dtype='object', length=598)
# Numeric Features: ['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'CNT_FAM_MEMBERS', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'HOUR_APPR_PROCESS_START', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'APARTMENTS_AVG', 'BASEMENTAREA_AVG', 'YEARS_BEGINEXPLUATATION_AVG', 'YEARS_BUILD_AVG', 'COMMONAREA_AVG', 'ELEVATORS_AVG', 'ENTRANCES_AVG', 'FLOORSMAX_AVG', 'FLOORSMIN_AVG', 'LANDAREA_AVG', 'LIVINGAPARTMENTS_AVG', 'LIVINGAREA_AVG', 'NONLIVINGAPARTMENTS_AVG', 'NONLIVINGAREA_AVG', 'APARTMENTS_MODE', 'BASEMENTAREA_MODE', 'YEARS_BEGINEXPLUATATION_MODE', 'COMMONAREA_MODE', 'ELEVATORS_MODE', 'ENTRANCES_MODE', 'LANDAREA_MODE', 'LIVINGAPARTMENTS_MODE', 'LIVINGAREA_MODE', 'NONLIVINGAPARTMENTS_MODE', 'NONLIVINGAREA_MODE', 'TOTALAREA_MODE', 'EMERGENCYSTATE_MODE', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE', 'DAYS_LAST_PHONE_CHANGE', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR', 'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK', 'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT', 'AMT_REQ_CREDIT_BUREAU_YEAR', 'DAYS_EMPLOYED_PERC', 'INCOME_CREDIT_PERC', 'INCOME_PER_PERSON', 'ANNUITY_INCOME_PERC', 'PAYMENT_RATE', 'NAME_TYPE_SUITE_Children', 'NAME_TYPE_SUITE_Family', 'NAME_TYPE_SUITE_Group of people', 'NAME_TYPE_SUITE_Other_A', 'NAME_TYPE_SUITE_Other_B', 'NAME_TYPE_SUITE_Spouse, partner', 'NAME_TYPE_SUITE_Unaccompanied', 'NAME_INCOME_TYPE_Businessman', 'NAME_INCOME_TYPE_Commercial associate', 'NAME_INCOME_TYPE_Maternity leave', 'NAME_INCOME_TYPE_State servant', 'NAME_INCOME_TYPE_Student', 'NAME_INCOME_TYPE_Unemployed', 'NAME_INCOME_TYPE_Working', 'NAME_EDUCATION_TYPE_Academic degree', 'NAME_EDUCATION_TYPE_Higher education', 'NAME_EDUCATION_TYPE_Incomplete higher', 'NAME_EDUCATION_TYPE_Lower secondary', 'NAME_EDUCATION_TYPE_Secondary / secondary special', 'NAME_FAMILY_STATUS_Civil marriage', 'NAME_FAMILY_STATUS_Married', 'NAME_FAMILY_STATUS_Separated', 'NAME_FAMILY_STATUS_Single / not married', 'NAME_FAMILY_STATUS_Unknown', 'NAME_FAMILY_STATUS_Widow', 'NAME_HOUSING_TYPE_Co-op apartment', 'NAME_HOUSING_TYPE_House / apartment', 'NAME_HOUSING_TYPE_Municipal apartment', 'NAME_HOUSING_TYPE_Office apartment', 'NAME_HOUSING_TYPE_Rented apartment', 'NAME_HOUSING_TYPE_With parents', 'OCCUPATION_TYPE_Accountants', 'OCCUPATION_TYPE_Cleaning staff', 'OCCUPATION_TYPE_Cooking staff', 'OCCUPATION_TYPE_Core staff', 'OCCUPATION_TYPE_Drivers', 'OCCUPATION_TYPE_HR staff', 'OCCUPATION_TYPE_High skill tech staff', 'OCCUPATION_TYPE_IT staff', 'OCCUPATION_TYPE_Laborers', 'OCCUPATION_TYPE_Low-skill Laborers', 'OCCUPATION_TYPE_Managers', 'OCCUPATION_TYPE_Medicine staff', 'OCCUPATION_TYPE_Private service staff', 'OCCUPATION_TYPE_Realty agents', 'OCCUPATION_TYPE_Sales staff', 'OCCUPATION_TYPE_Secretaries', 'OCCUPATION_TYPE_Security staff', 'OCCUPATION_TYPE_Waiters/barmen staff', 'WEEKDAY_APPR_PROCESS_START_FRIDAY', 'WEEKDAY_APPR_PROCESS_START_MONDAY', 'WEEKDAY_APPR_PROCESS_START_SATURDAY', 'WEEKDAY_APPR_PROCESS_START_SUNDAY', 'WEEKDAY_APPR_PROCESS_START_THURSDAY', 'WEEKDAY_APPR_PROCESS_START_TUESDAY', 'WEEKDAY_APPR_PROCESS_START_WEDNESDAY', 'ORGANIZATION_TYPE_Advertising' ...
# Categorical Features: []

# %% [markdown]
# ### Création de pipelines et de transformations

# %%
# Définition des transformations pour les données numériques et catégorielles
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %% [markdown]
# # Entraînement et évaluation de XGBoost

# %%
# Démarrage de la session MLFlow
mlflow.start_run(run_name="Optimized XGBoost with Fixed Thresholds", experiment_id=313886723643097310)

# Configuration de MLFlow pour le suivi des métriques
def log_metrics(y_true, y_pred, y_proba, threshold):
    auc = roc_auc_score(y_true, y_proba[:, 1])
    business_score_value = business_score(y_true, (y_proba[:, 1] > threshold).astype(int))
    mlflow.log_metric("AUC", auc)
    mlflow.log_metric("best_business_score", business_score_value)
    mlflow.log_metric("Optimized Threshold", threshold)

# Définition de la pipeline avec XGBoost et FixedThresholdClassifier
model_xgb = XGBClassifier(n_estimators=100, max_depth=3, learning_rate=0.1, random_state=10)
fixed_threshold_classifier = FixedThresholdClassifier(estimator=model_xgb, threshold=0.5, response_method='predict_proba')

model_xgb_pipeline = make_pipeline_imblearn(
    preprocessor,
    SMOTE(sampling_strategy=0.5, random_state=42),
    fixed_threshold_classifier
)

# Paramètres pour GridSearchCV
param_grid = {
    'fixedthresholdclassifier__estimator__max_depth': [3, 5],
    'fixedthresholdclassifier__estimator__learning_rate': [0.1, 0.2],
    'fixedthresholdclassifier__estimator__n_estimators': [100, 200],
    'fixedthresholdclassifier__estimator__subsample': [0.7, 1],
    'fixedthresholdclassifier__threshold': [0.1, 0.5, 1.0]
}

# Configuration de GridSearchCV avec une métrique personnalisée
business_scorer = make_scorer(business_score, greater_is_better=True, needs_proba=False, cost_fn=10, cost_fp=1)
grid_search = GridSearchCV(model_xgb_pipeline, param_grid, scoring=business_scorer, cv=3, verbose=2)
grid_search.fit(X_train, y_train)

# Récupération des résultats
best_params = grid_search.best_params_
best_score = grid_search.best_score_
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
y_proba = best_model.predict_proba(X_test)

# Log des métriques
log_metrics(y_test, y_pred, y_proba, best_params['fixedthresholdclassifier__threshold'])
print("Meilleurs paramètres : ", best_params)
print("Meilleur score business : ", best_score)

# Log dans MLFlow
mlflow.log_params(best_params)
mlflow.log_metric("best_business_score", best_score)

# Vérification et log des importances des caractéristiques
if hasattr(best_model.named_steps['fixedthresholdclassifier'].estimator, 'feature_importances_'):
    feature_importances = best_model.named_steps['fixedthresholdclassifier'].estimator.feature_importances_
    feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
    feature_importance_df.sort_values('Importance', ascending=False, inplace=True)
    print(feature_importance_df.head(20))

mlflow.sklearn.log_model(best_model, "model_v1")
mlflow.end_run()

# %%
bbbb

# %%
mlflow.start_run(run_name="Optimized XGBoost with Fixed Thresholds", experiment_id=313886723643097310)

# Pipeline de modélisation avec XGBoost et FixedThresholdClassifier
model_xgb = XGBClassifier(n_estimators=100, max_depth=3, learning_rate=0.1, random_state=10)
fixed_threshold_classifier = FixedThresholdClassifier(estimator=model_xgb, threshold=0.5, response_method='predict_proba')

model_xgb_pipeline = make_pipeline_imblearn(
    preprocessor,
    SMOTE(sampling_strategy=0.5, random_state=42),
    fixed_threshold_classifier
)

# Paramètres pour GridSearchCV
param_grid = {
    'fixedthresholdclassifier__estimator__max_depth': [3, 5],
    'fixedthresholdclassifier__estimator__learning_rate': [0.1, 0.2],
    'fixedthresholdclassifier__estimator__n_estimators': [100, 200],
    'fixedthresholdclassifier__estimator__subsample': [0.7, 1],
    'fixedthresholdclassifier__threshold': [0.1, 0.3, 0.5, 0.8, 1.0]
}

# Configuration de GridSearchCV
#scorer = make_scorer(threshold_auc_score, needs_proba=True)
business_scorer = make_scorer(business_score, greater_is_better=True, needs_proba=False, cost_fn=10, cost_fp=1)
grid_search = GridSearchCV(model_xgb_pipeline, param_grid, scoring=business_scorer, cv=3, verbose=2)
grid_search.fit(X_train, y_train)

# Afficher les résultats
print("Meilleurs paramètres : ", grid_search.best_params_)
print("Meilleur score business : ", grid_search.best_score_)

# Configuration de MLFlow pour le suivi
mlflow.log_params(grid_search.best_params_)
mlflow.log_metric("best_business_score", grid_search.best_score_)
mlflow.sklearn.log_model(grid_search.best_estimator_, "model_v1")
mlflow.end_run()
# Out:
# C:\Users\Farid\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py:610: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# Fitting 3 folds for each of 80 candidates, totalling 240 fits
# C:\Users\Farid\anaconda3\lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\Farid\anaconda3\lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time=  56.9s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time=  52.4s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time=  56.2s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time=  56.7s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time=  52.9s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time=  52.7s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time=  54.5s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time=  58.0s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time=  55.6s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time=  54.1s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time=  55.0s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time=  56.7s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time=  55.0s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time=  55.9s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time=  54.0s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time=  58.7s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time=  54.1s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time=  53.8s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time=  53.9s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time=  57.9s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time=  53.9s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time=  54.0s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time=  54.0s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time=  55.0s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time=  54.5s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time=  55.1s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time=  54.1s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time=  55.9s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time=  55.2s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time=  54.1s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time= 1.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time= 1.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time= 1.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time= 1.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 1.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time= 1.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time= 1.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time= 1.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time= 1.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time= 1.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time= 1.6min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time= 1.7min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.7min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.7min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 1.6min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time= 1.7min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time= 1.6min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.1, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time=  53.8s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time=  58.2s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time= 1.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time=  59.4s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time=  58.3s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time=  53.7s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time=  54.8s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time=  58.9s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time=  57.4s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time=  58.3s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time=  58.0s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time=  56.8s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time=  59.9s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time=  55.8s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time=  57.2s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time=  59.0s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time=  53.4s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time=  54.8s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time=  56.7s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time=  56.9s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time=  53.8s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time=  53.9s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time=  53.9s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time=  57.1s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time=  59.0s
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 1.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=3, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 1.2min
# ...
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.6min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.9min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.9min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time= 1.9min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time= 1.6min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time= 1.4min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time= 1.5min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time= 1.8min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=100, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time= 1.3min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time= 1.7min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time= 1.9min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.1; total time= 1.9min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time= 2.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time= 2.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.3; total time= 2.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.7min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 2.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.5; total time= 1.9min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 1.9min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 2.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=0.8; total time= 2.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 2.2min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 3.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=0.7, fixedthresholdclassifier__threshold=1.0; total time= 1.8min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 1.8min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 1.9min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.1; total time= 2.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time= 2.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time= 2.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.3; total time= 1.7min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time= 1.8min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time= 2.0min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.5; total time= 2.7min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time= 1.8min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time= 1.8min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=0.8; total time= 1.9min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time= 2.1min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time= 1.8min
# [CV] END fixedthresholdclassifier__estimator__learning_rate=0.2, fixedthresholdclassifier__estimator__max_depth=5, fixedthresholdclassifier__estimator__n_estimators=200, fixedthresholdclassifier__estimator__subsample=1, fixedthresholdclassifier__threshold=1.0; total time= 1.8min
# Meilleurs paramètres :  {'fixedthresholdclassifier__estimator__learning_rate': 0.1, 'fixedthresholdclassifier__estimator__max_depth': 5, 'fixedthresholdclassifier__estimator__n_estimators': 200, 'fixedthresholdclassifier__estimator__subsample': 1, 'fixedthresholdclassifier__threshold': 0.1}
# Meilleur score AUC :  0.7046460240848514
# C:\Users\Farid\anaconda3\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %% [markdown]
# ## Importance des caractéristiques
# Extraction de l'importance des caractéristiques après l'entraînement des modèles :
# * **Ajustement du préprocesseur :** J'ai ajusté le preprocessor sur les données d'entraînement, ce qui est essentiel pour préparer les features avant de récupérer leur nom.
#
# * **Gestion des features catégorielles :** J'ai conditionné l'ajustement des caractéristiques catégorielles et la récupération de leurs noms. C'est utile si la liste des caractéristiques catégorielles peut varier ou être vide.
#
# * **Extraction et affichage des importances des caractéristiques :** Après avoir entrainé le modèle, j'ai extrait l'importance de chaque caractéristique et affiché les plus importantes. Cela nous aide à identifier quelles variables ont le plus d'impact sur les prédictions du modèle.

# %%
# Assurez-vous que le préprocesseur est ajusté
preprocessor.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['NAME_CONTRACT_TYPE', 'CODE_GENDER',
#                                   'FLAG_OWN_CAR', 'FLAG_OWN_REALTY',
#                                   'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#                                   'AMT_CREDIT', 'AMT_ANNUITY',
#                                   'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH',
#                                   'DAYS_EMPLOYED', 'DAYS_REGISTRATION',
#                                   'DAYS_ID_PUB...
#                                   'REGION_RATING_CLIENT_W_CITY',
#                                   'HOUR_APPR_PROCESS_START',
#                                   'REG_REGION_NOT_LIVE_REGION',
#                                   'REG_REGION_NOT_WORK_REGION',
#                                   'LIVE_REGION_NOT_WORK_REGION',
#                                   'REG_CITY_NOT_LIVE_CITY',
#                                   'REG_CITY_NOT_WORK_CITY',
#                                   'LIVE_CITY_NOT_WORK_CITY', ...]),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  [])])

# %%
# Récupération des noms des caractéristiques
feature_names = list(preprocessor.transformers_[0][1].get_feature_names_out())
if categorical_features:
    feature_names += list(preprocessor.named_transformers_['cat'].named_steps['onehot'].get_feature_names_out(categorical_features))

# %%
# Récupération des importances des caractéristiques du modèle entraîné
feature_importances = grid_search.best_estimator_.named_steps['fixedthresholdclassifier'].estimator.feature_importances_

# Création et affichage du DataFrame
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
feature_importance_df.sort_values('Importance', ascending=False, inplace=True)
print(feature_importance_df.head(20))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8004\1123492077.py in <module>
#       1 # Récupération des importances des caractéristiques du modèle entraîné
# ----> 2 feature_importances = grid_search.best_estimator_.named_steps['fixedthresholdclassifier'].estimator.feature_importances_
#       3
#       4 # Création et affichage du DataFrame
#       5 feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
#
# ~\anaconda3\lib\site-packages\xgboost\sklearn.py in feature_importances_(self)
#    1312
#    1313         """
# -> 1314         b: Booster = self.get_booster()
#    1315
#    1316         def dft() -> str:
#
# ~\anaconda3\lib\site-packages\xgboost\sklearn.py in get_booster(self)
#     723             from sklearn.exceptions import NotFittedError
#     724
# --> 725             raise NotFittedError("need to call fit or load_model beforehand")
#     726         return self._Booster
#     727
#
# NotFittedError: need to call fit or load_model beforehand

# %%
# Vérifiez si le grid search a trouvé un meilleur estimateur
if hasattr(grid_search.best_estimator_.named_steps['fixedthresholdclassifier'].estimator, 'feature_importances_'):
    feature_importances = grid_search.best_estimator_.named_steps['fixedthresholdclassifier'].estimator.feature_importances_

    # Création et affichage du DataFrame
    feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
    feature_importance_df.sort_values('Importance', ascending=False, inplace=True)
    print(feature_importance_df.head(20))
else:
    print("Le modèle n'est pas correctement ajusté.")
# Out:
# Le modèle n'est pas correctement ajusté.

# %%
# Ajustement du préprocesseur sur les données d'entraînement
preprocessor.fit(X_train)

# %%
# S'assurer que preprocessor a des features catégorielles à traiter
if categorical_features:
    preprocessor.fit(X_train[categorical_features])
    feature_names_cat = list(preprocessor.named_transformers_['cat'].named_steps['onehot'].get_feature_names_out(categorical_features))
    feature_names = list(preprocessor.transformers_[0][1].get_feature_names_out()) + feature_names_cat
else:
    feature_names = list(preprocessor.transformers_[0][1].get_feature_names_out())

# %%
# Récupération des importances des caractéristiques du modèle entraîné
feature_importances = grid_search.best_estimator_.named_steps['xgbclassifier'].feature_importances_

# Affichage des importances des caractéristiques
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values('Importance', ascending=False)
print(feature_importance_df.head(20))

# %% [markdown]
# ## Outils d'interprétation des modèles
# Utilisation de SHAP pour l'interprétation des prédictions du modèle XGBoost :

# %%
import shap

# Calcul des valeurs SHAP
explainer = shap.TreeExplainer(grid_search.best_estimator_.named_steps['xgbclassifier'])
shap_values = explainer.shap_values(X_train)

# Visualisation
shap.summary_plot(shap_values, X_train, feature_names=feature_names)

# %%
# Création d'un objet Explanation pour les données de test
explainer = shap.Explainer(grid_search.best_estimator_.named_steps['xgbclassifier'])
shap_values_test = explainer(X_test)

# Visualisation pour une instance spécifique des données de test
index = 0  # Index de l'instance à expliquer
shap.force_plot(explainer.expected_value, shap_values_test[index].values, X_test.iloc[index])

# Visualisation de l'importance globale des caractéristiques
shap.summary_plot(shap_values_test.values, X_test, plot_type="bar")

# Diagramme détaillé pour une instance spécifique
shap.waterfall_plot(shap_values_test[index])
